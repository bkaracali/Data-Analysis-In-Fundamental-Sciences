# %% [markdown]
# # Mat388E Project

# %% [markdown]
# ## Relationship between Crime Rates, Socioeconomic Factors and Weather

# %% [markdown]
# **Name Surname:** Bora Karaçalı
#
# **Student Number:** 090220759
#
# **E-mail:** karacali22@itu.edu.tr

# %% [markdown]
# ## Datasets
#
# ### Crime Dataset

# %% [markdown]
# I obtained the crime data for the United States from the [Crime Data Explorer (CDE)](https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/home/), specifically from the NIBRS (National Incident-Based Reporting System) section labeled as "State Tables, Offences by Agency".

# %% [markdown]
# **The dataset comprises crime statistics for each of the 50 states in the USA for 2022. The data is categorized into three main types of crimes:**
#
# **Crime Against Persons:** This category includes offenses such as homicide, assault, and kidnapping, which directly harm individuals.
#
# **Crime Against Property:** This category encompasses crimes like burglary, theft, and vandalism, which involve the destruction or theft of property.
#
# **Crime Against Society:** This category covers offenses such as drug violations, prostitution, and gambling, which are considered harmful to society as a whole.
#
# For each state, the dataset provides information on the number of reported incidents for each type of crime, typically organized by year or time period.
#
# To illustrate, let's look an example for one state, Arizona:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df2= pd.read_csv('/Users/Bora/Desktop/poverty.csv')
df2
# Out:
#                                      Label (Grouping)  \
# 0    Population for whom poverty status is determined
# 1                                                 AGE
# 2                                      Under 18 years
# 3                                       Under 5 years
# 4                                       5 to 17 years
# ..                                                ...
# 64      Mean income deficit for unrelated individu...
# 65      Worked full-time, year-round in the past 1...
# 66      Worked less than full-time, year-round in ...
# 67                                       Did not work
# 68      Population in housing units for whom pover...
#
#    United States!!Total!!Estimate United States!!Total!!Margin of Error  \
# 0                     325,521,470                               ±24,959
# 1                             NaN                                   NaN
# 2                      71,241,523                               ±39,113
# ...

# %%
df3= pd.read_csv('/Users/Bora/Desktop/WeatherEvents_Jan2016-Dec2022.csv')
df3
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 0              W-1  Snow     Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2  Snow     Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3  Snow     Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4  Snow     Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5  Snow     Light  2016-01-08 13:54:00  2016-01-08 15:54:00
# ...            ...   ...       ...                  ...                  ...
# 8627176  W-9091890  Snow     Light  2022-12-21 23:00:00  2022-12-21 23:42:00
# 8627177  W-9091891  Snow  Moderate  2022-12-21 23:42:00  2022-12-21 23:53:00
# 8627178  W-9091892  Cold    Severe  2022-12-21 23:53:00  2022-12-24 02:53:00
# 8627179  W-9091893  Cold    Severe  2022-12-24 03:53:00  2022-12-24 07:53:00
# 8627180  W-9091894  Cold    Severe  2022-12-24 09:53:00  2022-12-24 11:53:00
#
# ...

# %% [markdown]
# ### Socioeconomic Dataset

# %% [markdown]
# ## Purpose of the Project
#
# The purpose of this project is to explore the relationships between crime rates, socioeconomic factors, and weather condicitons in a USA.
#
# **Hypothesis**: Higher level of unemployment and income inequality are positively correlated with increased crime rates. Additionaly, certain weather conditions, such as extreme temperatures or precipitation, are associated with higher crime rates.
#
# By integrating multiple datasets and applying various data analysis and Machine Learning techniques, the project aims to achieve the following objectives:
#
#
#
#
# **Crime Data and Socioeconomic Data Analysis:**
#
# 1. How do different socioeconomic factors correlate with different type of crimes?
#
# 2. Are there significant correlations between crime rates and socioeconomic factors such as unemployment rates, poverty levels, and income inequality?
#
# 3. Which socioeconomic factors have the most significant impact on crime rates?
#
# 4. Do certain demographic groups exhibit different crime trends based on socioeconomic factors?

# %% [markdown]
# 5. Does weather have an impact on the frequency of certain types of crimes?
#
# 6. What are the seasonal patterns in crime rates, and how do they correspond to changes in weather?
#
# 7. Are there specific weather conditions, such as temperature extremes, that influence crime rates more than others?
#
# 8. How do different types of crimes respond to changes in weather conditions?

# %% [markdown]
# 9. How do socioeconomic factors and weather conditions interact to influence crime rates?
#
# 10. Do certain socioeconomic factors moderate the relationship between weather conditions and crime rates?

# %% [markdown]
# ### Choice of Algorithms and Approach:
# Linear regression can provide insights to the direct impact of socioeconomic factors on crime rates.
#
# Decision trees can capture nonlinear relationships and interactions between variables.
#
# Support Vector Machines(SVM) are effective for classification tasks and be used to classify crime data into different categories based on socioeconomic and weather conditions.
#
# K-means clustering for identifying patterns or segments within the dataset.
#
#
#
# 3. * Random Forest regression model with crime rates as the target variable and socioeconomic factors as features.
#
#    * Extract feature importances from the trained model to determine the relative importance of each socioeconomic factor in   predicting crime rates.
#
#    * Features with higher importance scores are considered to have a more significant impact on crime rates.
#
#
#
#
# 4. * Using decision trees to predict demographic groups prone to specific types of crimes based on socioeconomic factors.
#
#    * k-nearest neighbor classification to identify similar demographic groups in terms of crime trends.
#
#    * Use hierarchical clustering to group demographic segments based on similarities in crime patterns.

# %% [markdown]
# ## Methodology

# %% [markdown]
# Since I have two different datasets, I will try to approach my analysis in several ways. Firstly, analyzing the relationships between crime rates and each of the other two factors separately and then compare the findings.
#
# 1. Crime Data and Socioeconomic Data Analysis:
#
#    * Starting by exploring the relationship between crime rates and socioeconomic factors.
#    * Linear Regression to quantify the relationship between crime and socioeconomic variables.
#    * Visualization with matplotlib such as histograms, heatmaps, scatter plots to have a better understanding how different socioeconomic indicators correlate with various types of crimes.
#    * Analyzing trends over time and across different demographic groups.
#    * Identifying any socioeconomic factors that appear to have a significant impact on crime rates.
#    * Using PCA to uncover underlying patterns in the data.

# %% [markdown]
# 2. Crime Data and Weather Data Analysis:
#
#    * Next, I will investigate the relationship between crime rates and weather conditions.
#    * Support Vector Machines (SVM) to model the relationship between crime rates and continuous weather variables.
#    * Using visualizations to examine how different weather variables correlate with crime rates.
#    * Analyzing seasonal patterns in crime rates and how they correspond to changes in weather.
#    * Identifying any weather conditions (temperature extremes) that can influence crime rates.
#    * Applying clustering algorithm K-Means to identify distinct patterns in crime rates based on weather conditions.

# %% [markdown]
# 3. Integrated Analysis:
#
#    * Finally, I will integrate all three datasets to gain a understanding of the factors influencing crime rates.
#    * Answering how socioeconomic factors and weather conditions interact to impact crime rates.
#
# By analyzing the relationships between crime rates and each of the other two factors separately and then integrating the findings, gain deeper insights into the complex interplay of socioeconomic factors, weather conditions, and crime rates.

# %% [markdown]
# ## Timeline

# %% [markdown]
# **Week 1-2 (April 1-15): Data Collection and Preparation**
#
# Gathering crime data, socioeconomic data, and weather data.
# Explore the datasets to understand their structures and variables.
#
# **Week 3-4 (April 15-29): Crime Data and Socioeconomic Data Analysis**
#
# Exploratory data analysis (EDA) to examine the relationship between crime rates and socioeconomic factors and visualization.
#
#
# **Week 5-6 (April 29 - May 13): Crime Data and Weather Data Analysis**
#
# Investigate the relationship between crime rates and weather conditions, Support Vector Regression (SVR) to model the relationship and visualization how different weather variables correlate with crime rates.
#
#
# **Week 7-8(May 13-27): Integrated Analysis**
#
# Integrating all three datasets to understand factors influencing crime rates comprehensively.
# Using Neural Networks for capturing complex interactions.
#
#
# **May 28: Final Analysis and Reporting**
#
# Finalize analysis, summarize findings, including insights into the interplay of socioeconomic factors, weather conditions, and crime rates.

# %% [markdown]
# ### Software
# * Python 3
# * Essential Python Libraries (pandas, numpy, scikit-learn, matplotlib, etc.)
# * Jupyter Notebook
